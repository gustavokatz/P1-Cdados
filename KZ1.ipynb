# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: _____
#
# Nome: _____

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Gustavo\Documents\INSPER2\Cdados\Nova pasta\P1-Cdados

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
filename = 'PS5.xlsx'

# %%
train = pd.read_excel(filename).drop(columns=['0: Não relevante\n1: Relevante\n2: Muito relevante'])
train.head(5)
# Out:
#                                          Treinamento  Classificacao
# 0  fala galera, livezinha no rainbow, vem ai dar ...              1
# 1  atualizações\n\nxbox series x : 10.3gb\nxbox o...              2
# 2  – season 6 resumo de tamanhos!\n\n– xbox: 26 g...              2
# 3  @loud_voltan vai jogar ps5 né veia? \n\nbom de...              1
# 4  @ocervejeiro_ ps5 pro com certeza. https://t.c...              1

# %%
test = pd.read_excel(filename, sheet_name = 'Teste').drop(columns=['0: Não relevante\n1: Relevante\n2: Muito relevante'])
test.head(5)
# Out:
#                                                Teste  classificacao2
# 0  @micalibruno apesar de ser um game de 2018, oc...               1
# 1  @ileohhh @fnstatusbr @brasil_fortnite no ps5 a...               1
# 2  rt @tiagohardco: ontem eu tava jogando pillars...               1
# 3  @heyzubshere pois é kfhskdsdfsdf e o ps5 tá da...               1
# 4  @maiconkusterk sua namoradaa quebrar seu ps5, ...               0

# %% [markdown]
# ___
# ## Classificador automático de sentimento

# %% [markdown]
# Faça aqui uma descrição do seu produto e o que considerou como relevante ou não relevante na classificação dos tweets.
#
# Para poder classificaf os tweets como não relevantes, relevantes ou muito relevantes, foi utilizado um conceito dado por Dale Carnegie que explica apenas criticas não são uteis para se obter melhora. Com isso nossa categoria para não relevante foram as criticas negativas, para relevante foram as criticas positivas e para o muito relevante foram comparações com concorrentes

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
# Limpeza de caracteres desnecessários:
import re 

#função de limpeza removendo as pontuações
def cleanup(text):
    caracteres = '[!-.:,:?;/@")(|,[\n].' 
    reconstrucao = re.compile(caracteres)
    text_subbed = re.sub(reconstrucao, '', text)
    return text_subbed

# %%
#aqui temos são separadas as palavras de cada tweet de acordo com sua classificação e em sequência limpadas.

train0 = train.loc[(train['Classificacao'] == 0),:]
train1 = train.loc[(train['Classificacao'] == 1),:]
train2 = train.loc[(train['Classificacao'] == 2),:]
train0 = cleanup(str(list(train0['Treinamento']))).split()
train1 = cleanup(str(list(train1['Treinamento']))).split()
train2 = cleanup(str(list(train2['Treinamento']))).split()


for tweet in (test['Teste']):
    tweet = (tweet.split())
   # print(tweet)
    for palavra in tweet:
        palavra = cleanup(palavra)
       # print(palavra)
    print ((cleanup(str(tweet))).split())
# Out:
# ['icalibruno', 'pesar', 'e', 'er', 'm', 'ame', 'e', '018ctopath', 'raveler', 'm', 'stilo', 'ue', 'e', 'grada', 'uitoerá', 'ue', 'hega', 'ara', 's4s5]']
# ['leohhh', 'fnstatusbr', 'brasil_fortnite', 'o', 's5', 'cabou', 'e', 'ançar', 'lk', 'ô', 'nsioso', 'ms', 'ara', 'ssa', 'tualizaçãoarece', 'ue', 'omei', 'afé', 'om', 'nergético', 'kkkk']
# ['rt', 'tiagohardcontem', 'u', 'ava', 'ogando', 'illars', 'f', 'ternity', 'deadfire', 'o', 's5', 'ogo', 'stá', 'ncrível', 'e', 'indoas', 'udo', 'arece', 'ais', 'ento', 'o…']
# ['eyzubshere', 'ois', 'fhskdsdfsdf', 's5', 'á', 'ando', 'ns', 'iziuntão', 'eio', 'ue', 'ale', 'ena']
# ['aiconkusterk', 'ua', 'amoradaa', 'uebrar', 'eu', 's5as', 'mg', 'umca', 'conteceu', 'mgaq', 'umca', 'ive', 's5', 'em', 'amorada']
# ['absurdo', 's5', 'á', 'il']
# ['ngleooficial', 'omara', 'ue', 'ony', 'ance', 'm', 's5', 'om', 'b']
# ['inclusiveueria', 'oder', 'echar', 'ogo', 'o', 's5', 'a', 'ala', 'ontinuar', 'o', 'esmo', 'ave', 'uando', 'osse', 'ogar', 'o', 's4', 'o', 'uarto', 'ttpsoiqsop0hiu']
# ['saturnorock', 'gabriell_medina', 'arielsis', 'cho', 'ue', 'q', 'ai', 'air', 'ersão', 'e', 'S5ue', 'ara', 'ão', 'tualiza', 'rátis', 'ra', 'uem', 'egou', 'a', 'lusu', 'enho', 'le', 'omprado', 'ó', 'ue', 'ão', 'inha', 'ogado', 'indaô', 'ogando', 'elo', 'ype', 'a', 'lus]']
# ['🛠️', 'tualização', 'iberadas5', '5gbfortnite', 'fortnitezeropoint', 'ttpsopfiksbbmb']
# ['jogando', 'gora', 'orizon', 'ero', 'awn', 's5', 'ttpsosflbdzrrx']
# ['confesso', 'ue', 'emporada', 'o', 'ortnite', 'oderia', 'er', 'ido', 'aisídeo', 'o', 'anal', 'ive', 'eita', 'ra', 'estar', 'ogoiz', 'ive', 'ela', 'rimeira', 'ez', 'iretamente', 'o', 's5', 'ony', 'a', 'e', 'arabéns', 'ela', 'ualidade', 'ue', 'le', 'razeixei', 'oces', 'ia', 'aid', 'om', 'impática', 'euminecatt', 'om', 'ia', 'odos]']
# ['os', 'estores', 'e', 'ráfico', 'evem', 'urar', 'e', 'é', 'unto', 'ue', 'u', 'enho', 'rana', 'ra', 'm', 's5', 'ttpso7z7mscosw']
# ['vo', 'icar', 'alando', 'o', 'intendo', 'witch', 'o', 's5', 'inha', 'ó', 'te', 'la', 'divinhar', 'u', 'uero', 'm', 'os', 'ois']
# ['odrigocoelhoc', 'marynikky_', 'oelhou', 'omprei', 'a', 'réenda', 'ma', 'teelbook', 'aguei', '790entei', 'ogar', 'ogo', 'a', 'rimeira', 'emana', 'e', 'ançamento', 'o', 's5', 'em', 'hanceevolvi', 'gora', 'epois', 'ue', 'iver', 'erteza', 'ue', 'ogo', 'stá', 'm', 'erfeitas', 'ondiçõesu', 'ou', 'omprar', 'e', 'ovo', 'sn', 'eria', 'ermômetro', 'e', 'ogo', 'stá', 'k']
# ['ps5', 'á', 'iferente', 'kkkkkk', 'ttpsogrgawzdzy']
# ['porque', 'té', 'esmo', 'ogando', 'o', 's5', 'om', 'ersão', 'o', 's4', 'ogo', 'ofrivelight', 'ity', 'ma', 'idade', 'riste', 'e', 'ortaá', 'em', 'nimo', 'e', 'ogar']
# ['rgalwav', 'srlemu', 'im', 'á', 'alendo', '60', 'il', 'idensale', 'endermagina', 'uantos', 's5', 'á', 'ra', 'omprar']
# ['runapenilhas', 'ewe', 'iga', 'isso', 'ue', 'aneiro', 'á', 'aratin', 'ai', 'esolver', 'eus', 'poblemaweottpsoda0epthux']
# ['ablo_peixoto', 'ncrível', 'omo', 'u', 'ão', 'e', 'mpressionaria', 'e', 'sso', 'osse', 'rint', 'e', 'lgum', 'ogo', 'o', 's5iu']
# ['arloseduardocd', 'm', 'xemplo', 'laro', 'ue', 'ejo', 'emons', 'ouls', 's5', 'ualidade', 'as', 'exturas', 'anta', 'ue', 'e', 'stá', 'm', 'k', 'u', 'ãosso', 'ão', 'az', 'iferençainha', 'artes', 'ue', 'u', 'lhava', 'alava', 'sso', 'uase', 'omo', 'quela', 'emo', 'a', 'pic', 'al', 'osso', 'sperar', 'ra', 'er', 'ue', 'd', 'rá', 'ostrar]']
# ['lvaroafduarte', 'joaoamoedonovo', 'ão', 'ocê', 'uem', 'aga', 'ua', 'ovóuncionária', 'ública', 'o', 'unicípio', 'ue', 'e', 'eu', 'quele', 's5', 'om', 'gio]']
# ['itocastrillo', 'migo', 'sse', 'ogo', 'á', 'icando', 'om', 'esmo', 'u', 'entei', 'no', 'assado', 'azendo', 'orça', 'as', 'esisti', 'q', 'inda', 'ava', 'odo', 'ugadoas', 'ô', 'ensando', 'm', 'oltar', 'uando', 'ançar', 'e', 's5']
# ['igozfn', 'o', 's5', 'oi', 'b', 'ô', 'boa']
# ['ps5', 'gb', 's4', '8', 'u', 'o', 'orrendo']
# ['laystation_br', 'sonybrasil', 'eu', 'ontrole', 'o', 's5', 'ão', 'sta', 'arregando', 'a', 'udei', 's', 'onfigurações', 'e', 'ornecer', 'nergia', 'e', 'oras', 'ara', 'empre', 'le', 'ão', 'arrega', 'a', 'estei', 'onectar', 'o', 'c', 'bm', 'ão', 'unciona', 'uero', 'uporte', 'ão', 'cho', 'o', 'eu', 'ite', 'hat', 'nline', 'u', 'umero', 'e', 'elefone']
# ['rksedu', 'foioguto', 's5', 'u', 'ilha]']
# ['rt', 'ignbrasilerdeu', 's', 'rincipais', 'ovidades', 'e', 'ntemão', 'e', 'reocupemariananeryf', 'raz', 's', 'otícias', 'ue', 'ocê', 'recisa', 'aber', 'o', 'dailyfix…']
# ['👉lendário', 'ogo', 'atchet', 'amplank', 'rátis', 's4', 'amps5👈', 'ttpsomnheq5f38', 'ia', 'youtube']
# ['rt', 'manicoedmiltonenho', '0mil', 'omprar', 's5', 'u', 'bortar', 'issão', '😹😹']
# ['ortalcafiune', 'cho', 'em', 'aio', 'amer', 'í', 'einó', 'alta', 'anhar', 'm', 's5', 'kkk']
# ['hysiquegamepl2', '_pedro_0908', 'nikkury', 'ssista', 'nalise', 'eita', 'pós', 'atchc', 'erá', 'ps', 'o', 's5', 'scilando', 'ais', 'abirintite', 'e', 'éio']
# ['arbonoalpha', 'sonystaheroi', 'enryucrf', 'windowsclubbr', 'sou', 'ais', 'c', 'aster', 'aceas', 'eu', 'onsole', 'e', 'ida', 's4', 'e', 'á', 'uando', 'icar', 'arato', 'm', 's5']
# ['arkmelocoton', 'ai', 'ssistir', 'vento', 'elo', 'c', 'u', 's5]']
# ['rt', 'conversadesofara', 'uem', 'uiser', 'proveitar', 's', 'ogos', 'o', 'ame', 'assem', 'box', 'eries', 'o', 'stoque', 'a', 'mazonra', 'uem', 'uer', 'ntrar', 'a', 'ova…']
# ['nouthh', 'rovavelmente', 'h', 'akecho', 'ai', 'ais', 'er', 'lataforma', 'or', 'ausa', 'o', 's5', 'eries']
# ['atualização', 'o', 's5gb']
# ['atualização', 'o', 'ornite', 'o', 's4', 'e', '0gb', 'o', 's5', 'ó', 'gbtf', 'ei]']
# ['iranhamorales1', 'noiacoisas', 'arantir', 's5']
# ['preço', 's599€', 'amazon', 'sreço', 'boxntra', 'irecto', 'o', 'amepassssim', 'ica', 'ifícilplaystationptttpsogruk9jnsf']
# ['inetando', 'ds', 'o', 'éuá', 'parecendo', 't', 'omercial', 'o', 's5', 'a', 'lobo']
# ['arconmalu', 'miga', 'ica', 'ica', 'í', 'ra', 'omprar', 's5']
# ['arcosvalverde', 'ssa', 'firmação', 'stava', 'o', 'orizonteludido', 'oi', 'uem', 'ão', 'uis', 'er', 'ssoasta', 'er', 's5', 'om', 'endas', 'racas', 'or', 'nquanto']
# ['rt', 'ialarodrigokkkgatilhosmood', 'metadinhaxs', 'u', 'ueria', 'm', 's5', 'unado', 'om', 'tx']
# ['inoano', 'em', 'á', 'ola', 'ente', 'o', 'lame', 'uahuahua', 'nica', 'oisa', 'ue', 'cho', 'ue', 'ode', 'contecer', 'ra', 'air', 'sse', 'patch', 'ony', 'uerer', 'azer', 'm', 'emaster', 'esse', 'ame', 'ro', 's5', 'bm', 'ma', 'ersão', 'e', 'c']
# ['astorxbox', 'om', 'ólar', 'as', 'abeças', 'ançamentos', 'hegando', '0050', 'o', 's5', 'ó', 's', 'ais', 'esavisados', 's', 'asoquistas', 'ão', 'icar', 'em', 'ssinar', 'amepass', 'qui', 'o', 'rasil']
# ['ickedjuliani', 'as', 'u', 'o', 'alando', 'o', 'amepass', 'esmoão', 'o', 'alando', 'a', 'lus', 'm', 'i', 'lus', 'a', 'ogo', 'ro', 's4as', 'iberou', 'ma', 'ista', 'e', 'ogos', 'ro', 's5', 'c', 'ode', 'ogar', 'o', 's4', 'e', 'c', 'iver', 'm', 's5]']
# ['opiasso', 'p1000qi', 'sim_paint', 'om', 'iaão', 'ei', 'o', 's5', 'm', 'specialas', 'eralmente', 'sse', 'ipo', 'e', 'aterial', 'em', 'nroladoberto', 'as', 'ontasle', 'sou', 'ra', 'echarelo', 'enos', 'spero', 'ue', 'enha', 'ido', 'ssou', 'le', 'urro', 'esmo🏻\\u200d♂️']
# ['ifbtt', 'oce', 'o', 'recisa', 'ntrar', 'o', 'ite', 'u', 'pp', 'egar', 's', 'ogos', 'eao', 'recisa', 'e', 's5', 'hauhs']
# ['rt', 'gm_whainnytualização', 'isponível', 'o', 's5', 'ps5share', 'ttpsoxl6m27qzw']
# ['agora', 'ronto', 'ode', 'er', 'm', 'box', 'ne', 'at', 'ssinar', 'amepass', 'm', '021c', 'brigado', 'er', 'box', 'eries', 'u', 'm', 's5q', 'e', 'c', 'm', 'obretãoonystas', 'ucumbam', 'odos]']
# ['¿comprar', 'l', 'e8', 'ara', 's5', 'ara', 'a', 'c']
# ['oaooz28', 'i', 'te', 'u', 'uero', 'm', 's5']
# ['obrigada', 'ela', 'ive', 'morescansaoogo', 'e', 'or', 'ogar', 's5', 'loud_babi']
# ['rt', 'felipenetoronunciamento', 'espeito', 'a', 'cusação', 'e', 'rime', 'ontra', 'egurança', 'acional53021', 'brigado', 'odos', 'ue', 'ssistirem', '…']
# ['eatherziml', 'u', 'ai', 'anhar', 'm', 's5', 'u', 'ei', '😭😭']
# ['foi', 'nunciado', 'ue', 'uper', 'omberman', 'nline', 'hegará', 'ratuitamente', 'ara', 'box', 'nebox', 'eries', 's4s5intendo', 'witch', 'c', 'm', 'reve', 'ma', 'oucura', 'nline', 'ara', '4', 'ogadores', 'om', 'quela', 'ogabilidade', 'lássicansioso🎮😱🎉💣', 'railerttpsogxtketj1k', 'ttpsocdb1lnqix']
# ['obdaibes', 'u', 'ompraria', 'elularsperava', 'reço', 'o', 's5', 'aixar', 'baixar', 'astante', 'omprava', 's5', 'ais', 'arde']
# ['opaem', 'ogo', 'iberado', 'o', 's4', 's5', 'ssa', 'emana', 'rksedu', 'az', 'xperimentttpso9jwovknht', 'ia', 'youtube', 'ttpsofaak8iozx']
# ['rick', 'nd', 'orty', 'iteralmente', 'á', 'ez', 'd', 'e', 'raça', 'ra', 'intendoas', 'esmo', 'ssim', 'uem', 'á', 'atrocinando', 'érie', 'agando', 'ra', 'les', 'azerem', 'd', 's5orranintendo']
# ['nstatusbr', 'brasil_fortnite', 'aleraue', 'oras', 'ai', 'er', 'tualização', 'ara', 's4s5', 'ps5', 'ara', 'uem', 'iver', 'laro']
# ['o', 's5ei', 'a', 'ual', 'ste', 'ttpso2xmkuf3x2']
# ['nessa', 'emp', 'u', 'ou', 'sar', 'ontrole', 'e', 's5', 'ttpsownqnmthlo']
# ['às', 'ezes', 'udo', 'ue', 'ocê', 'recisa', 'air', 'a', 'ona', 'e', 'onforto', 'ar', 'm', 'asso', 'm', 'ireção', 'os', 'eus', 'onhosttpsowqg1kdtmb', 'twitch', 'twitchbr', 'twitchbrasil', 'livestream', 'streaming', 'jogos', 'videogame', 'xbox', 'ps5', 'pc', 'pcgamer', 'games', 'gamerbr', 'euamovideogame', 'liveontwitch', 'ttpso9rrddmeac']
# ['gustavo_gf', 'kkkkkkkkkkkkkkk', 'em', 'ogo', 'em', 'a', 'onsertado', 'indaó', 'e', 'olocarem', 'xclusivo', 'ra', 's5as', 'ó', 'em', 'ogo', 'uim', 'ra', 's5']
# ['ilosofiamderna', 'starlightzie__', 'acro', 's5uanto', 'eve', 'ustar]']
# ['ill__robert', 'eu', 'm', 'p', 'uito', 'om', 'esse', 's5ue', 'u', 'cho', 'em', 'einho', 'ahaha']
# ['nova', 'ela', 'e', 'arregamento', 'o', 'ortnite', 'o', 's5ia', 'skintrackercom', 'ttpsopivtgzhqh']
# ['xh_fanboy', 'foioguto', 'az', 'elhor', 'ela', 'a', 'arede', 'orraão', 'o', 's5']
# ['runa_boscarol', 'm', 's5']
# ['joguinhoeveelaxante', 'ranquiloue', 'ransmite', 'az', 'almariara', 'echar', 'oite', '😍❤️\\U0001f971🎮🌈🕹️🎭⛏️🔨\\U0001fa93🛠️🔫🏹🗡️🧬💉\\U0001fa78💊', 'tlou2', 'thelastofus2', 'ps5', 'ps4', 'gaymer', 'gamer', 'playstation5', 'nerd', '😁🤟', 'm', 'ão', 'aulorazil', 'ttpsonhjfdogja']
# ['atualização', 'isponível', 'ro', 's5amanhogbfortnite']
# ['1000qi', 'ooctdmonica', 'apa', 'u', 'á', 'enhoó', 'alta', 's5']
# ['china', 'ede', 'mpréstimo', 'e', '000', 'eais', 'e', 'inizin', 'ara', 'agar', 's5', 'o', 'heo']
# ['ony', 'ue', 'ouve', 'om', 's5ão', 'ai', 'hegar', 'o', 'rasil', 'ão]']
# ['xbox', 'eries', 'm', 'stoque', 'ada', 'o', 's5iai', 'ssa', 'ony]']
# ['xpectrool', 'tualização', 'á', 'eve', 's5', 'icou', 'e', 'ora']
# ['rt', 'caioosccp', 'essoa', 'ue', 'em', 'm', 's5', 'ra', 'ogar', 'ortnite', 'á', 'orreu', 'or', 'entro']
# ['oga_dan', 's', 'xclusivos', 'inha', 'stratégia', 'eguintebox', 'witch', 'goras5', 'á', 'diei', 'ra', 'ns', 'nos', 'uando', 's', 'xclusivos', 'e', '50', 'eais', 'ustarão', 'ns', '9', 'm', 'romoi', 'aleintendo', 'á', 'onhecemos', 'or', 'ão', 'aixar', 's', 'reçosas', 'om', 'laystation', 'á', 'ra', 'omprar', 'epois', 'ranquilo]']
# ['uiz_fernandorj', 'matheusfort46', 'em', 'ontar', 'ue', 'ale', 'a', 'iblioteca', 'assada', 'uita', 'ente', 'o', 'lsystation', 'em', '50', 'ogos', '00', 'les', 'uerem', 'evar', 'om', 'les', 'a', 'uropa', 's', 'essoas', 'o', 'ifa', 'em', 'rupos', 'ificil', 'rocar', 'omunidade', 'esse', 'egmento', 'u', 'ejo', 'ue', 'ony', 'inda', 'ra', 'r', 'em', 'om', 's5', 'le', 'ançou', 'em']
# ['motivos', 'ara', 'omprar', 'm', 's5', 'té', 'omentoerottpsoctmpabgqy']
# ['e', 'ão', 'ra', 'uebrar', 'ecordes', 'ony', 'em', 'ançava', 's5foi', 'egundo', 'ardware', 'ais', 'endido', 'm', 'evereiro', 'ttpso6fcnejqwh']
# ['athanvit0r', 'kkkkkkkk', 'á', 'ede', 'm', 's5']
# ['ougmad4k', 'ostar', 'ó', 'creenshots', 'onito', 'as', 'e', 'ir', 'esmo', 'ídeo', 'a', 'igital', 'oundry', 'abe', 'ue', 'ersão', 'a', 's5', 'orre', '0', 'ps', 'ocked', 'nquanto', 'a', 'eries', 'esmo', 'orrendo', 'om', 'esolução', 'ais', 'lta', 'em', 'm', 'ramerate', 'ais', 'nstável', 'om', 'au', 'ramepacing', 'les', 'onsideram', 'ersão', 'a', 's5', 'elhor']
# ['andx_rejected', 'pensologoehisto', 'andrizek', 'ndré', 'adimeu', 'asal️']
# ['9k', 'm', 's5', 'aralho', 'ueria', 'anto', 'er', 'ica', '😭😭😭']
# ['oecoolxbox', 'omprou', 's5', 'ria', 'ogar', 'lguma', 'oisase', 'ufu', 'iseravi', 'ão', 'ai', 'a', 'ficina', 'ttpsok1qunqwdh']
# ['demon', 'ouls', 'o', 's5', 'a', 'onito', 'emaisuero', 'ogar', ']']
# ['vídeo', 'ovottpsoehaxa26ts', 'residentevil6', 'residentevil', 'gaming', 'youtube', 'ps5', 'xbox', 'ttpso3xsrgluhu']
# ['se', 'ony', 'astasse', 'anto', 'inheiro', 'abricando', 's5', 'uanto', 'asta', 'azendo', 'ropaganda', 'o', 'esmo']
# ['sorriso', 'lharas', 'ssim', 'e', 'c', 'iver', 'kate', 'm', 's5', 'i', 'ttpsogifjgbxr2']
# ['nguet1ed', 'lk', 'omprando', 'alzao', 'ra', 'ogar', 'o', 'eu', 's5']
# ['incero_joel', 'sse', 'one', 'ovo', 'latinum', 'om', 'utra', 'oupagemem', 'acanaó', 'ão', 'á', 'ra', 'sperar', 'esempenho', 'e', 'm', '40', 'eleas', 'u', 'so', 'empo', 'odoanto', 'ra', 'rampar', 'uanto', 'ro', 's5]']
# ['eu', 'o', 'ypadolguém', 'e', 'á', 'm', 's5', 'lmddss', 'ttpso2i10ls2jc']
# ['rt', 'comentonaogr', 'las', 'em', 'ontrolesô', 'entindo', 'amos', 'er', 'otalmente', 'rocados', 'elo', 's5', 'ttpsovertma757']
# ['utupieri', 'em', 'lguém', 'omprando', 'm', 's4', 'or', 'ku', 'i', 'esses', 'reços', 'ntendi', 'ue', 'ma', 'ntrada', 'ara', 's5ue', 'egue', 'sgotado', 'or', 'quik', 'o', 's4', 'at', 'té', 'u', 'ago', 'ra', 'eixar', 'le', 'qui]']
# ['mortal', 'hellnhanced', 'dition', 's5', 'm', 'om', 'oulslike', 'ecânica', 'o', 'arden', 'ransforma', 'ameplay', 'm', 'lgo', 'ais', 'gressivo', 'ue', 'stamos', 'costumados', 'om', 'ouls', 'm', 'erals', 'iferentes', 'hells', 'ão', 'ma', 'ariada', 'o', 'ogossim', 'omo', 's', 'rmas', 'ovimentação', 'o', 'ersonagem', 'stranha', 'ttpsoz3gtijxrd']
# ['ae_douglas', 'em', 'm', 's5ó', 'ode']
# ['por', 'euspareceram', 'ns', 'rês', 'weets', 'eguidos', 'alando', 'o', 's5', 'u', 'á', 'ui', 'gual', 'ma', 'adela', 'a', 'nternet', 'er', 'e', 'inha', 'eposto', 'stoqueas', 'ão', 'inha', 'ada', 'epressão', 'ampágrimas']
# ['haisinhah', 'imagemanticon', 's5', 'indo']
# ['autalizasão', 'á', 'stá', 'isponível', 'ara', 's4s5', 'ttpsolxarobkwt']
# ['oioguto', 'a', 'inha', 'asa', 'té', 'm', 's5', 'agado', 'eria', 'indo']
# ['rt', 'noinstante_n10_ogo', 'a', 'iscórdia', 'uliette', 'parte', 'rotagonistasulietteamilla', 'ilberto', 'oadjuvantesarlarojotaa…']
# ['4nofps', 'ada', 'e', 'ov', 'a', 'orra', 'o', 's5', 'sf']
# ['oioguto', 'u', 'a', 'otar', 'm', 'lástico', 'ó', 'ra', 'ão', 'airs5', 'ersonalizado', 'ue', 'inguém', 'ai', 'er']
# ['gnbrasil', 's5egundo', 'onsole', 'ais', 'endidoual', 'oi', 'rimeiro]']
# ['ifoork', 'as', 'o', 's5', 'a', 'uito', 'ais', 'aro']
# ['ackysozinho', 'vastowendigo', 'u', 'ais', 'imples', 'ó', 'omprar', 'm', 'box', 'eries', 'u', 's5', 'ronto']
# ['ifbtt', 'as', 'amepass', 'ao', 'ollection', 'o', 's5', 'splus', 'ollection', 'oi', 'eita', 'ara', 'oce', 'ogar', 's', 'ogos', 'o', 's5', 'orque', 'uita', 'ente', 'ao', 'ogou', 'les', 'o', 's4', 'gora', 'em', 'm', 's5', 'm', 'ez', 'e', 'oce', 'omprar', 'les', 'ony', 'implesmente', 'e', 'eu', 'haushuahs']
# ['rt', 'andygamer1ovidade', 'o', 'anal', '👍', 'ink', '️', 'ttpsoldroge6po', '️resident', 'vil', 'o', 's5', 'egando', 'roféu', 'e', 'he', 'nife', '️bora…']
# ['se', 'sse', 'vo', 'e', 'áscoa', 'e', '30', 'eais', 'ão', 'ier', 'om', 's5', 'entro', 'em', 'uero']
# ['rt', 'girlsonsixcrimson', 'eist💥', 'manhã6s', 'ervidores', 'ntram', 'm', 'anutenção', 'ra', 'hegada', 'a', 'ova', 'eason', 'lores', '🇷', 'á', 'á', 'nimadão…']
# ['mds', 'u', 'ô', 'ão', 'riste', 'lguém', 'e', 'á', 'm', 's5]']
# ['canal', 'ovo', 'a', 'oxinhaai', 'olar', 'ives', 'e', 's5ixaster', 'dição', 'e', 'ideottpsokx6x8pkjk']
# ['ondavocals', 'lazuletter', 'brwjsn', 'for_nyvitx', 'rckyeon', 'ai', 'e', 'a', 's5', 'i']
# ['uliano72679795', 'xhatake2k', 'ntendiu', 'unca', 'avia', 'ssistido', 'ada', 'elee', 'onfundi', 'ntão', 'ois', 'esse', 'ideo', 'í', 'le', 'ala', 'stá', 'om', 'S5', 'ele', 'e', 'rrepende', 'e', 'er', 'endido', 'ne', 'le', 'e', 'mpolga', 'm', 'ouco', 'ala', 'S5', 'ó', 'a', 'au', 'kkas', 'elevei', 'ssa', 'arte]']
# ['contra', 'úmerosão', 'á', 'rgumentos', 'ttpso7gl4l1uuc']
# ['noooossa', 's5', 'inda', 'ropaganda', 'ena', 'ue', 'inguém', 'em', 'inheiro', 'kkkk']
# ['nstatusbr', 'brasil_fortnite', 's5', 'omeçou', 'lgo', 'ttpsohddv3yg7n']
# ['tdowiusley', 'essoa', 'resta', 'ente', 'á', 'abe', 'ue', 'ão', 'anvlz', 'ma', 's5']
# ['gorarasilva', 'p1000qi', 'cho', 'ue', 'esfriamento', 'o', 's5', 'eito', 'om', 'etal', 'iquido', 'ntão', 'ão', 'uda', 'uita', 'oisaas', 'é', 'ode', 'er', 'ue', 'u', 'steja', 'alando', 'esteira']
# ['rt_z2', 'felipinholpp', 'matiaskaw', 'windowsclubbr', 's5', 'rita', 'vosa', 'le', 'or', 'ma', 'ora', 'ota', 'leo', 'ra', 'er', 'e', 'ão', 'ica', 'ma', 'eleza']
# ['só', 'ueria', 'm', 's5', 'gora']
# ['eu', 'uando', 'omprar', 'eu', 's5', 'ttpsoyly6wyfyx']
# ['imaginem', 'ntrar', 'um', 'orteio', 'ara', 'oder', 'omprar', 'ma', 's5']
# ['vpmbr', 'e', 'hem', 'uim', 'e', 'sar', 'esmoão', 'erde', 'adao', 's5', 'em', 'em', 'sso', 'ambém']
# ['eu', 'ou', 'nico', 'ue', 'uer', 'er', 'inheiro', 'ra', 'omprar', 'm', 's5c', 'ra', 'u', 'ogarertezaeus', 'onhos', 'ão', 'em', 'nfantis', 'p']
# ['eu', 'chei', 't', 'indo', 'uem', 'e', 'era', 'er', 'm', 's5', 'ssim', 'ttpsostishxze8']
# ['n', 'ntendicordei', 'ão', 'i', 'm', 's5', 'a', 'inha', 'ama']
# ['richgarciacruz', 's5', 'física]']
# ['sony', 'ança', 'ais', 'nidades', 'a', 's5', 'stou', 'arto', 'e', 'entar', 'ompraras', 'stá', 'empre', 'ora', 'e', 'tock]']
# ['andajojo1', 'hil', 'ó', 'oi', 'á', 'esejar', 'oa', 'orte', 'alvez', 'ensando', 'm', 'ma', 'quisição', 'uturaá', 'ue', 'stúdio', 'ndependente', 'pesar', 'e', 'star', 'azendo', 'm', 'ogo', 'ara', 'S5', 'ue', 'alvez', 'ossa', 'er', 'xclusivo', 'emporário']
# ['rovecto_drops', 'sony', 'aralhoarece', 'ue', 'e', 's5', 'loparão', 'erá', 's6']
# ['abrielgalaxy99', 'ena', 'ue', 'ssa', 'ão', 'istória', 'ompletainda', 'ão', 'ançar', 'ontinuação', 'ó', 'ue', 's5', 'ttpsop9ofxnbk8']
# ['oioguto', 's5', 'eio', 'e', 'm', 'ospicio']
# ['edrotriforce', 'ossa', 'ogo', 'á', 'indo', 'o', 's5', 'á', 'ouco']
# ['rt', 'kronemberg10ueria', 'm', 's5']
# ['oao_eddie', 'lhaão', 'e', 'arece', 'mpossível', 'ançarem', 'm', 'mt', 'aniax', 'o', 's5cas', 'a', 'rimeira', 'ersão', 'cho', 'ifícil']
# ['ordox', 'u', 'om', 'ogava', 'o', 's5']
# ['avynigv', 'ão', 'amorando🏽']
# ['bethesda', 'á', 'oi', 'provada', 'o', 'arne', 'as', 'asas', 'ahiaaiu', 'one', 'ovo', 'ro', 'boxogo', 'om', 'ps', 'oost', 'u', 'qui', 'sperando', 'róximo', 'eme', 'o', 'canaldocoelho_', 'om', 's5', 'ele']
# ['chemittep', 'ps5_fr', 'ravo', '👏']
# ['rt', 'honorluscachief117br', 'u', 'o', 'evendo', 'm', 'rabalho', 'statistico', 'omparando', 'roporção', 'e', 'suarios', 'ue', 'ontactaram', 'esquisaram', 'or', 'ara…']
# ['rlupaplays', 'gramiliki_', 'enda', 'e', 'ogos', 'e', 's5', 'uais', 'ogos', 'e', 's5', 'oda', 'sta', 'ue', 'ai', 'o', 'apaoua', 'u', 'uropaop', '0', 'ao', 'em', 'ogo', 'e', 's5', 'migolias', 's5', 'ao', 'em', 'ogo', 'ovo', 'esde', 'ançamento', 'ele', 'rimeiro', 'ogo', 'em', 'gora', 'eturnal', 'eus', 'abe', 'e', 'ai', 'restar', 'sse', 'ogokkk]']
# ['trilha', 'onora', 'o', 'ackboy', 'ps4s5', 'oa', 'emais]']
# ['boxtruepower', 'aprecdenint', 'ó', 'e', 'er', 'dquirido', 'm', 's5', 'u', 'á', 'cho', 'ma', 'ergonha']
# ['ramiliki_', 'la', 'ó', 'squeceu', 'e', 'visar', 'ue', 'ony', 'ao', 'sta', 'ucrando', 'om', 's5', 'ada', 's5', 'endido', 'm', 'rejuízokkkkkkk]']
# ['atualização', 'isponível', 'o', 's5', 'ps5share', 'ttpsoxl6m27qzw']
# ['mano', 'u', 'o', 'ncantado', 'om', 'ualsense', 'controle', 'o', 's5', 'as', 'u', 'uero', 'andar', 'azer', 'ma', 'esa', 'ro', 'cntão', 'eu', 'inheiro', 'e', 'esume', 'uma', 'oisa', 'u', 'utraqp', 'u', 'aso']
# ['oisepatrick', 'as', 's', 'ogos', 'stão', 'om', 'ps', 'ravadorecisaria', 'ue', 'rópria', 's', 'izesse', 'sso', 'cho', 'ue', 'ão', 'irá', 'ão', 'edoapesar', 'ue', 'cho', 'ue', 'apaz', 'e', 'enderem', 'm', 'emaster', 'e', 'b', 'ro', 's5', 'c', 'om', '0fps']
# ['ajudae', 'anhar', 'ste', 'assatempo', 'o', 'meusjogospt', 'playstationpt', 'om', 'ogos', 'ara', 'ps4', 'ps511anosmj', 'ttpsoifxchl7hk']
# ['rt', 'wesley_jhonatass5', 'sgotado', 'm', 'odos', 's', 'ugares', 'o', 'undo', 'enos', 'a', 'eira', 'e', 'ueimados', '😂😂😂', 'ttpsoiyltoiez4']
# ['iankitacg', 'm', 'aptop', 'eria', 'ais', 'til', 'ue', 'm', 's5']
# ['fakequevoceama', 'ceito', 'm', 's5kay]']
# ['andaescarlate', 'brksedu', 'foioguto', 'aralhoai', 'nfiar', 'm', 's5', 'a', 'uceta]']
# ['era', 'ó', 'm', 's5', 'a', 'inha', 'ida']
# ['tarkillerdark', 'ara', 'uando', 'c', 'egar', 's5', 'or', 'avor', 'ogue', 'q', 'ocê', 'ai', 'entir', 'quela', 'ostalgia', 'oa', 'inda', 'er', 'ma', 'xperiência', 'e', 'ova', 'eração', 'ratamento', 'ue', 'eram', 'o', 'ogo', 'icou', 'ncrível]']
# ['roia', 'eldengoso', 'o', 's5', 'eio', 'esma', 'oisa']
# ['fico', 'eliz', 'ue', 'tarfield', 'ai', 'odar', 'k', 'o', 's5ia', 'outube']
# ['ensoblog', 'egalas', 'uero', 'er', 'uncionando', 'o', 'eu', 's5']
# ['yakujp', 'u', 'u0', 'inutos', 'e', 'orrada', 'alendo', 'm', 's5']
# ['oga_dan', 'hu', 'em', 'ntro', 'esse', 'érito', 'orque', 'sso', 'arte', 'ltra', 'ositiva', 'o', 'amepass', 'alo', 'e', 'essoa', 'ue', 'uer', 'ogarei', 'á', 'ogo', 'o', 'S5', 's', 'essoas', 'squecem', 'ue', 'om', 'empo', 's', 'reços', 'ão', 'aindo', 'las', 'odem', 'er', 'odos', 's', 'onsoles', 'em', 'enhum', 'roblema']
# ['rt', 'carlinhostrollais', 'm', 'orteio', 'eu', 'ara', 'ocêsstou', 'orteando', 's5', 's4eja', 'omo', 'articiparttpsoi2nmkhxrt', 'carlinhos…']
# ['limpando', 'etup', 'playstation5', 'ps5', 'psvita', 'vitaisland', 'setup', 'ttpsoktznj4yij']
# ['mais', 'm', 'orteio', 'ara', 'ocês', 'carlinhostroll', 'stá', 'orteando', 's5', 's4eja', 'omo', 'articiparttpsoeifcgxfru', 'carlinhosps5']
# ['rt', 'tutupieriu', 'ão', 'ou', 'avor', 'e', 'desapegar', 'e', 'ens', 'ateriais', 'q', 'nfinito', 'niverso', 'le', 'spírito', 'iriri', 'ororó', 'as', 'u', 'cho', 'ue…']
# ['anilogentili', 'felipeneto', 'i', 'i', 'ó', 'gua', 'ater', 'o', 'umbum', 'ue', 'cs', 'té', 'e', 'nemum', '😂😂😂', 'ue', 'elícia]']
# ['eu', 'cho', 'mpressionante', 'omo', 'amepass', 'o', 'box', 'oda', 'ora', 'nclui', 'm', 'ilhão', 'e', 'ogos', 'ovos', 'inda', 'a', 'ra', 'sar', 'o', 'box', 'ne', 'o', 'cnquanto', 'a', 'ony', 'ó', 'unciona', 'o', 's5', 'inguém', 'unca', 'ais', 'eve', 'otícia', 'ele]']
# ['ihstopico', 'caomunista1917', 'eraí', 'ue', 'u', 'ô', 'a', 'ila', 'essas', 'érias', 'ías', 'osso', 'sperar', 'ony', 'ançar', 'ogos', 'e', 's5', 'ntess']
# ['sonhei', 'ue', 'omprei', 's5]']
# ['rt', 'honorluscachief117br', 'ive', 'mpressão', 'e', 'ue', 'o', 'ês', 'e', 'ançamento', 'inha', 'uito', 'ais', 'roblema', 'o', 's5', 'endo', 'eportado', 'ela', 'aleranqu…']
# ['chelolive', 'lha', 'lien', 'ue', 'o', 'nstalando', 'o', 's5', 'ano']
# ['androsub_zero', 'ucro', 'as', 'ony', 'ende', 's5', 'om', 'rejuízokkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk']
# ['1000qi', 'ou', 'azer', 'sso', 'ó', 'alta', 's5']
# ['tô', 'á', 'anto', 'empo', 'sperando', 's5', 'riei', 'm', 'anço', 'tée', 'ão', 'uer', 'er', 'omprado', 'ntão', 'ambém', 'ão', 'o', 'ompra']
# ['andadumb', 'ô', 'rocurando', 'té', 'j', 's', 'oroa', 'ra', 'e', 'ancaru', 'ou', 'mas', 'nrolada', 'ela', 'á', 'igado', 'eço', 'ra', 'antar', 'm', 'omida', 'araeço', 'm', 's5', 'azoo']
# ['ramiliki_', 'omo', 'gora', 'á', 'm', 'uturo', 'ncerto', 'ara', 's5', 'box', 'eriess', 'evs', 'ão', 'riorizar', 'witch', 'té', 'e', 'onvenceram', 'ue', 'ova', 'eração', 'e', 'ato', 'm', 'om', 'egócio']
# ['fifa', '1', 'elhor', 'ame', 'ogo', 'e', 'utebol', 'e', 'ideo', 'ame', 's3', 's4', 's5', 'ttpsotxrssmmdz', 'ia', 'youtube']
# ['nacabanellos', 'lhae', 'alar', 'ue', 'u', 'endia', 'sse', 's5a', 'uase', '0', 'il', 'onsoleps', 'omprava', 'm', 'onsole', 'ais', 'arato']
# ['azoocajoe', 'em', 'alem', 'rquivo', 'e', '0', 'b', 'ue', 'evo', '0', 'inutos', 'ra', 'aixar', 'o', 'c', 'u', 'emoro', 'ora', 'lguns', 'inutos', 'o', 's5']
# ['rt', 'foiogutoior', 'ue', 'u', 'cho', 'sse', 's5', 'indo']
# ['arry_styles', 'arry', 'e', 'ompra', 'm', 's5]']
# ['rt', 'pastorxboxada', 'ia', 'u', 'e', 'urpreendo', 'ais', 'om', 's', 'ecursos', 'o', 's5', 'ovimentação', 'utomática', '🤣🤣🤣']
# ['aqui', 'emos', 'm', 's5', 'ersonalizadole', 'xclusivottpsouykviievv']
# ['hinismo', 'e', 'iras', 'stes', 'ais', 'ethesda', 'finserdes', 't', 'o', 'atálogo', 'ornava', 's', 'ão', 'ixe', 'escobrir', 'utros', 'ogos', 'ora', 'os', 'aioresaqui', 'ouco', 'ó', 'ens', 'bisoft', 'a', 's', 'uvido', 'hes', 'alte', 'oderioançamento', 'a', 's5', 'im', 'oi', 'iasco', 'ens', 'uase', 'ogos', 'ovos', 'enhunsd', 'pgrades']
# ['andonato96', 'omo', 'c', 'uer', 'ue', 'u', 'ompre', 'eu', 's5', 'a', 'ua', 'oja', 'e', 'c', 'em', 'sse', 'au', 'ostoane', 'juda', 'e', 'judar']
# ['achei', 'onceituale', 'm', 'ia', 'u', 'iver', 'm', 's5', 'ou', 'edir', 'ra', 'lgum', 'rimo', 'riança', 'ustomizar', 'ra', 'im', 'ttpsooyizphuvx']
# ['eitorataide', 'playstation_br', 'omprei', 'ogo', 'epois', 'ue', 'inha', 's5á', 'té', 'oje', 'a', 'aixaogando', 'odos', 's', 'ames', 'm', '0fps', 'estaca', 'emais', 's', '0fps', 'eleó', 'ou', 'ogar', 'do', 'iver', 'pdate', 'e', 'psu', 'uando', 'ão', 'iver', 'ais', 'ada', 'sm']
# ['rlupaplays', 'nis56952365', 'gramiliki_', 'ntes', 'ue', 'osse', 'sso', 'araraduziram', 'to', 'al', 'alavra', 'ucro', 'í', 'propositalmente', 'ra', 'er', 'eceita', 'eceita', 'reço', 'nidendidasão', 'ignifica', 'adaó', 'ue', 'e', 'astou', 'ais', 'inheiro', 'smó', 'ue', 'witch', 'usta', '200~00', 's5', '400~00', 'ado', 'diota', 'ra', 'anchete', 'lickbait']
# ['oelmar015', 'ão', 'á', 'm', 's5', 'ra', 'la]']
# ['preço', 'e', 'm', 'omem', 'ranha', 'orales', 's5', 'ttpsomyprnfmzb']
# ['uvoch', 'aprecdenint', 'ão', 'aiu', 'ídeo', 'e', 'omparação', 'om', 's5ez', 'om', 's4', 'ro']
# ['att', 'o', 's5', 'bano', 'o', 's4', '0', 'ezes', 'aior', 'kkkkk']
# ['tamanho', 'a', 'tualização', 's5', 'gb']
# ['se', 'ier', 'm', 's5', 'u', 'omproe', 'ão', 'em', 'ttpsofdwbwgkx2']
# ['acho', 'ue', 'ony', 'inha', 'ue', 'daptar', 's5', 'ra', 'sse', 'esign', 'ttpsow51tyn4q7']
# ['ps5', 'inda', 'ndam', 'sgotadas]']
# ['rihelsecron', 'amos', 'e', 's5']
# ['para', 'udorailer', 'e', 'ungeons', 'ampragonsark', 'lliancecaba', 'e', 'air', 'os', 'ostraua', 'ameplay', 'uas', 'lassessony', 'playstation', 'ps5', 'ps4', 'xbox', 'xboxseriesx', 'xboxone', 'nintendoswitch', 'nintendo', 'pc', 'microsoft', 'steam', 'darkalliance', 'dungeonsanddragons', 'ttpsomjjkpqrnj']
# ['mais', 'm', 'orteio', 'ara', 'ocês', 'carlinhostroll', 'stá', 'orteando', 's5', 's4eja', 'omo', 'articiparttpsoxhko35gwk', 'carlinhosps5']
# ['não', 'ai', 'er', 'u', 'anhando', 'm', 's5', 'sse', 'no', 'ttpsoqw6lnydcj']
# ['onystaheroi', 'windowsclubbr', 'erói', 'onysta', 'lagrado', 'e', 'asturbando', 'a', 'rente', 'e', 'm', 's5']
# ['bethesda', 'gora', 'box', 'gora', 'uem', 'oderá', 'e', 'ar', 'm', 'box', 'eries', 'ttpsonwji1zt28', 'ia', 'youtube', 'xboxgamepass', 'ps5', 'gamer', 'legendagem', 'bethesda']
# ['trust', 'presenta', 's', 'uscultadores', 'xt', '23', 'arusompatíveis', 'om', 's5', 'c', 'ttpsoerxu3vqm0']
# ['heisgxntvr', 'ia', '9ceito', 'm', 's5', '️☺️']
# ['mano', 'em', 'ue', 'im', 'm', 's5', 'entro', 'e', 'ma', 'vo', 'e', 'áscoaq', 'eu', 'eus', 'agulho', 'á', 'aro']
# ['astorxbox', 'e', 'e', 'embro', 'em', 'igital', 'raude', 'uando', 'ecebeu', 's5', 'ohn', 'inneman', 'utro', 'á', 'alaram', 'ue', 'ão', 'eio', 'abo', 'assado', 'lguns', 'ias', 'les', 'firmaram', 'ue', 'ra', 'osso', 'star', 'rrado']
# ['o', 'ínimo', 'ue', 'u', 'spero', 'rêmio', 'entro', 'e', 'ada', 'vo', 'er', 'ma', 'e', 'artes', 'e', 'm', 's5', 'ra', 'ocê', 'esmo', 'ontar', 'ttpsodi2m7yovq']
# ['trust', 'presenta', 's', 'uscultadores', 'xt', '23', 'arusompatíveis', 'om', 's5', 'c', 'ttpsoxs5yozcjh', 'ttpso9fgiumwaw']
# ['trust', 'presenta', 's', 'uscultadores', 'xt', '23', 'arusompatíveis', 'om', 's5', 'c', 'ttpsoiaiktm9y7']
# ['ekgg_', 'a', 'opiando', 'rquivo', 'e', 'tualização', 'qui', 'o', 's5', 'o', 's4', 'inda', 'em', 'tualizou']
# ['ia', 'té', 'ompra', 's5ais', 'niversário', 'a', 'elena', 'ma', 'emana', 'ntes', 'o', 'eu', 'ogo', 'epois', 'iagemí', 'ai', 'hora', 'o', 'rabalho😂👨\\u200d👧👨\\u200d👧']
# ['gxt', '23', 'arus', 'ão', 's', 'ovos', 'uscultadores', 'a', 'rustompatíveis', 'om', 's5', 'c', 'ttpsoyayilp5a2']
# ['enatogoulart08', 'em', 'm', 's5', 'unto]']
# ['rt', 'ignportugalovas', 's5', 'onfirmadas', 'ara', 'sta', 'emanattpsoanvnvkcnf']
# ['uliano72679795', '_pedro_0908', 'nikkury', 'he', 'ivision', 'stava', 'em', 'mbiente', 'oogoem', 'og', 'bi', 'isse', 'eria', 'orrigidoois', 'e', 'ia', 'evoeiro', 'o', 's5', 'ava', 'ra', 'entir', 'tmosfera', 'ttpsow4njrb9gj']
# ['rasanoinverno', 'anhar', 'm', 's5', 'm', '21', 'ltra', '👍🏻']
# ['a', 'otícia', 'ue', 's5', 'oi', 'egundo', 'ardware', 'ais', 'endidouem', 'oi', 'rimeiroo', 'ortátilzinho', 'a', 'intendoas', 'ony', 'em', 'ue', 'r', 'ra', 'ancheteem', 'ue', 'ar', 'm', 'eito', 'e', 'abar', 'onykkkkkk', 'ttpsoizahx6qut']
# ['rt', 'ocervejeiro_ae', 'onystasá', 'ompraram', 'ior', 'ersão', 'e', 'utriders', 'or', '79', 'o', 's4s5u', 'ogarei', 'em', 'usto', 'dicional', 'ay', 'ne', 'o', 'am…']
# ['mais', 'm', 'orteio', 'ara', 'ocês', 'carlinhostroll', 'stá', 'orteando', 's5', 's4eja', 'omo', 'articiparttpsoggxgxshe0', 'carlinhosps5']
# ['rt', 'joecoolxboxomprou', 's5', 'ria', 'ogar', 'ontinuação', 'e', 'ellbladeau', 'a', 'ua', 'unda', 'omprou', 's5', 'ria', 'ogar', 'ontinuação', 'e', 'oomau…']
# ['ackinb01809916', 'beansanddough', 'a', 'rrumar', 'lguma', 'oisa', 'e', 'til', 'azereu', 'migo', 'á', 'rabalhar', 'ompre', 'm', 's5asse', 'esto', 'o', 'no', 'ogando', 'pidermanelo', 'enos', 'ai', 'star', 'azendo', 'lgo', 'ue', 'ão', 'eja', 'ostando', 'erda', 'o', 'witter]']
# ['eu', 'ó', 'retendo', 'ogar', 'sse', 'ogo', 'uando', 'u', 'iver', 'm', 's5', 'uando', 'air', 'ersão', 'e', 's5']
# ['ellos', 'enha', 'qui', 'ota', 'o', 's5', 'ttpsowkpp4lbs1']
# ['hukte', 'ita', 'e', 'á', 'm', 's5', 'ue', 'u', 'aço', 'q', 'c', 'uiser', '🥵']
# ['mandaoufer', 'osso', 'alar', 'omo', 'magino', 'csltura5', 'exualidadeão', 'ei', 'stado', 'ivilamo', 'om', 'eu', 's5', 'ue', 'eu', 'b', 'dade5', 'olpe', 'u', 'adoolpe', 'osta', 'e', 'imãoão', 'uer', 'e', 'ar', 'eu', 's5', '🏻', 'egarialvz']
# ['illespie_arya', 'm', 'vo', 'a', 'ony', 'ai', 'ir', 'm', 's5', 'ompleto', 'í', 'om', 'ovo', 'ow]']
# ['rielsis', 'odem', 'e', 'riticaras', 'esde', 'ue', 'u', 'omprei', 's5ão', 'ntrou', 'o', 'amepass', 'enhum', 'ogo', 'ue', 'u', 'stou', 'ogandontão', 'ra', 'im', 'az', 'iferença]']
# ['iovannipaulo7', 'lk', 'ai', 'e', 'ender', 'ras', 'eias', 'a', 'omprar', 's5']
# ['asmodeus', 'kyrim', 'otr', 'skyrim', 'skyrimse', 'asmodeus', 'demon', 'kingofdemons', 'crossover', 'skyrimscreenshots', 'skyrimmods', 'skyrim4k', 'bethesda', 'toddhoward', 'pcgamer', 'xbox', 'ps5', '4k', '4kgaming', 'elderscrolls', 'theelderscrolls', 'skyrimmemes', 'skyrimdaily', 'gamers', 'playstation', 'ttpsomhorgys5r']
# ['arbarataaa', '🥵', 'uero', 'm', 's5']
# ['iwinches69', 'e', 'u', 'omprar', 'm', 's5']
# ['rt', 'ingridguimaraesu', 'e', 'dentifico', 'om', 'oucurinha', 'eio', 'esastrada', 'a', 'uliette]']
# ['lançamento', 'ta', 'ara', 's5', 'box', 'eries', 'ad', 'ames', 'ycoon', 'ttpsoxcrcjbfri', 'ia', 'youtube']
# ['afaelgrn', 'ai', 'icar', 'ada', 'ez', 'ais', 'ifícil', 'u', 'er', 'empo', 'e', 'igar', 's5']
# ['passei', 'nos', 'horando', 'or', 'm', 's4i', 'gora', 'reço', 'ue', 'u', 'nvesti', 'esse', 'c', 'ava', 'ra', 'er', 'omprado', 'ns', 'rêsu', 'm', 's5']
# ['aio_gunnar', 'u', 'cho', 'ue', 'ão', 'upera', 'ow', '018', 'as', 'spero', 'ue', 'u', 'steja', 'nganadou', 'ueria', 'uito', 'omprar', 's5', 'ntes', 'o', 'ançamento', 'e', 'ow', 'or', 'sso', 'uanto', 'ais', 'fiarelhor]']
# ['osgabi6', 'ossa', 'im', 'pq', 'argas', 'gua', 'izeste', 'ssoem', 's5', 'or', 'ia]']
# ['só', 'ueria', 'ellblade', 'ro', 's5', 'oe', 'icrosoft', 'eus', 'oiola', 'eixa', 'u', 'rincar', 'om', 'quela', 'squizofrênica', 'ais', 'm', 'ouco']
# ['arielsis', 'e', 'rrisco', 'izer', 'ue', 'erviço', 'deal', 'ara', 'ogador', 'rão', 'em', 'ondições', 'e', 'agar', 'reço', 'ue', 's', 'ogos', 'ão', 'hegando', 'quiaqui', 'ais', 'ois', 'eses', 'ou', 'egar', 'eries', 'ó', 'ou', 'egar', 'S5', 'ra', 'ogar', 's', 'xclusivos', 'a', 'onyue', 'u', 'osto', 'uitoultiplataforma', 'o', 'ame', 'ass]']
# ['oga_dan', 'lus', 'elhorou', 'uitoas', 'u', 'a', 'enho', 'amepass', 'o', 'c', 'enho', 's5', 'witch', 'as', 'u', 'ntendo', 'uem', 'scolhe', 'laystation', 'esmo', 'ao', 'endo', 'c', 'u', 'box', 'az', 'entido', 'ela', 'lus', 'tual', 'uito', 'elhor', 'ra', 'uem', 'ao', 'oga', 'uito', 'empogora', 'uem', 'oga', 'ais', 'quantidadebox', 'elhor', 'esmo']
# ['uck_off_matt', 's', 'ezes', 'u', 'enso', 'ue', 's', 'erdas', 'ue', 's', 'anboys', 'o', 'box', 'alam', 'em', 'a', 'ropria', 's', 'ria', 'odar', 'ogo', '440pe', 's', 'ultis', 'ossem', 'ara', 's5', 'rdna0', 'tfssim', 'omo', 'eria', 'mais', 'oderosoem', 'uvida', 'enhuma', 'e', 's5', 'osse', '8tf', 'verclock', 'dna1]']
# ['não', 'ou', 'e', 'ar', 'm', 's5', 'ttpsostu5cwymu']
# ['rturplier', 'ope', 's5', 'a', 'emote', 'lay', 'm', '080p', 'ualidade', 'astante', 'ecente']
# ['rt', 'pastorxboxdmi', 'ão', 'ecessário', 'ara', 's5iz', 'erente', 'e', 'roduto', 'a', 'ony', 'ra', 'azer', 'k', 'ake', 'om', 'esolução', 'inâmica', 'ealmente', '…']
# ['sobre', 'im', 'a', 'oja', 'o', 's3spero', 'ue', 'ony', 'uturamente', 'aça', 'ma', 'ategoria', 'e', 'ps3', 'lássicos', 'ssim', 'omo', 'em', 'a', 'oja', 'o', 's3', 'ogos', 'lássicos', 'e', 's1', 's2odando', 's', 'ogos', 'e', 's3', 'ia', 'mulação', 'o', 's5u', 'ue', 'elo', 'enosermita', 'ownload', 'e', 'ogos', 'e', 's3', 'ia', 'snow', 'ia', 'mulação]']
# ['s3brasil', 'elo', 'eito', 'ó', 'ou', 'onseguir', 'omprar', 's5', 'uando', 'ançarem', 's6', 'á', 'oda', 'ssa', 'eração']
# ['2021', 'em', 'lk', 'ue', 'inda', 'aga', 'au', 'ra', 'ráficosso', 'ão', 'eixou', 'e', 'er', 'elevante', 'ipons', 'nos', 'trás', 'uando', 'odo', 'ogo', 'a', 'em', 'ráfico', 'om', 'uficiente', 'oda', 'rande', 'novação', 'm', 'ráfico', 'o', 'm', 'feito', 'ovo', 'nútilora', 'ue', 'm', 'c', 'e', '019', 'a', 'ence', 'bosta', 's5', 'm', 'raficods]']
# ['laystation_br', 'ança', 's5as', 'e', 'ança', 's4', 'om', 'ontrole', 'ma', 'erdaior', 'eu', 'ue', 'a', 'a', 'arantia', 'ão', 'onsigo', 'em', 'andar', 'ra', 'onserto', 'u', 'roca]']
# ['a', 'ony', 'esperdiçou', 's5', 'om', 'rojota', 'iat', 'om', 'ocah']
# ['amuhell', 'a', 'dd', 'istória', 'ai', 'er', 'm', 'inal', 'eliz', 'imai', 'air', 'ais', 'emaster', 'esses', 'ames', 'e', 's3', 'ro', 's5ó', 'ue', 'inal', 'eliz', 'ai', 'er', 'ra', 'ony', 'ue', 'ai', 'ender', 'ogo', 'elho', 'om', 'reço', 'ovinho', 'm', 'olha', 'onyonystandoemon', 'ouls', 'ó', 'nício', 'a', 'eva', 'e', 'emasteremake']
# ['rt', 'nideologiaxbox', 'eries', 'ma', 'meaça', 'eal', 'ara', 's5onysta', 'ota', 'a', 'abeça', 'ue', 'ogo', 'ó', 'ráficoer', 'ais', 'arato', 'odar', 'odos', '…']
# ['attsof', 'antonioaca', 'id_folkvang', 'nacaow', 'eli_lamartine', 'frankfangames1', 'sso', 'uim', 'ra', 'uem', 'em', 's3', 'ita', 'as', 'ra', 'uem', 'em', 'm', 's4s5', 'ão', 'uda', 'ada]']
# ['cervejeiro_', 'ada', 'uff', 'ony', 'ai', 'ir', 'om', 'ma', 'etro', 'onstro', 'o', 's5', 'lim', 'ronota', 'í]']
# ['ilico777', 'u', 'ava', 'ensando', 'm', 'egar', 'm', 's5', 'uando', 'aisse', 'm', 'limudei', 'e', 'deia]']
# ['não', 'ão', 'uimgora', 's5', 'em', 'm', 'otivo', 'ra', 'icar', 'uardado', 'uando', 'ão', 'uncionar', 'ais', 'ttpsowtycqaai9']
# ['5', 'ias', 'em', 'eu', 'witch', 'ntem', 'assou', 'or', 'inha', 'abeça', 'tíra', 'sse', 'e', 'im', 'omprar', 'm', 's5', 'j', 'eu', 'nstagram', 'ó', 'em', 'núncio', 'e', 's5', ']']
# ['uck_off_matt', 'onfesso', 'ue', 'inha', 'urpresa', 'eside', 'o', 'ato', 'a', 'oja', 'igital', 'inda', 'ender', 'ogos', 'o', 's3ue', 'á', 'oi', 'escontinuado', 'nosustificaria', 'ma', 'erta', 'omoção', 'e', 'ouvesse', 'etrocompatibilidade', 'om', 's4', 'u', 's5as', 'ão', 'ejo', 'uita', 'azão', 'rática', 'm', 'romover', 'enda', 'e', 'ogos', 'o', 's3', 'ão]']
# ['pensando', 'obre', 'bandonar', 'deia', 'o', 's5', 'omprar', 'm', 'c']
# ['olucci_up', 'uando', 'air', 'ersão', 'ra', 's5', 'u', 'ão', 'ompro', 'q', 'deio', 'pg', 'm', 'rimeira', 'essoa']
# ['acho', 'ssa', 'eração', 'o', 'e', 'box', 'odaseem', 'ondições', 'icar', 'agando', '50', 'eais', 'm', 'ogo', 'e', 's5refiro', 'omprar', 'm', 'caixa', 'agar', 'm', 'amepass', 'om', '00', 'ogo', 'oaony', 'á', 'irando', 'ma', 'ilha', 'a', 'uta', 'gual', 'intendo']
# ['enoh_00', 'icrosoft', 'elo', 'enos', 'em', 'ma', 'bordagem', 'ais', 'onesta', 'e', 'olha', 'sso', 'm', 'luguelom', 'amepass', 'ony', 'inha', 'brigação', 'e', 'mular', 'sso', 'udo', 'o', 's5']
# ['nesse', 'omeço', 'e', 'eração', 'ai', 'evar', 'mas', 'orradas', 'om', 's5', 'spero', 'ue', 'sso', 'irva', 'ra', 'udar', 'lgumas', 'oisas', 'mportantes', 'entro', 'a', 'mpresa']
# ['otfilipe', 'ê', 'costuma', 'ápido', 'ual', 'ontrole', 'egou', 'e', 's5', 'u', 'box]']
# ['enxxmoraes', 'imm', 'ipo', 'ocê', 'ue', 'em', 's5', 'le', 'á', 'uncionando', 'e', 'aneira', 'ais', 'ecente', 'ntão', 'ão', 'eria', 'm', 'rejuízo', 'ão', 'rande']
# ['evin_jhairo', 'playstation_br', 'eu', 'rotherreio', 'c', 'eja', 'ã', 'a', 'lataforma', 'om', 'ertezaeu', 'onselhoega', 'm', 'eries', 'u', 'ara', 'ogarnd', 'air', 'ma', 'ersão', 'ais', 'tualizada', 'o', 's5', 'c', 'ompraom', 'ue', 'á', 'ai', 'er', 'ais', 'ogos', 'o', 'tualmentema', 'deiapenas', 'ei', 'uais', 'eus', 'ostos]']
# ['🔴🎮', 'o', 'ivoem', 'ogar', 'ontra', 'odrigo', 'o', 'panhando', 'os', 'ãs', 'o', 'ortal', 'ombat', '1', 'ttpsobbkuscdt9', 'ttpsobbkuscdt9', 'ttpsobbkuscdt9', 'ps4', 'mortalkombat', 'ps5', 'xbox', 'xboxseriesx', 'irmaospiologo', 'ttpsolnhrypkhb']
# ['aio_gunnar', 'uvido', 'uito', 'ue', 'ssas', 'orradas', 'ejam', 'inimamente', 'fetivas', 's5', 'á', 'endendo', 'ue', 'em', 'gua', 's', 'ogos', 'o', 'c', 'ão', 'razer', 'ma', 'ova', 'rande', 'enda', 'ara', 'ony']
# ['quase', 'eses', 'e', 's5', 'á', 'eu', 'roblema', 'e', 'rift', 'o', 'ualsense']
# ['hukte', 'u', 'ô', 'uardando', 'inheiro', 'astante', 'empo', 'ambému', 'ensei', 'ue', 'a', 'baixar', 'om', 's5', 'as', 'ó', 'umentouma', 'miga', 'inha', 'onseguiu', 'egar', 'm', 'or', '000', 'oucos', 'o', 'inal', 'o', 'nou', 'sperei', 'gual', 'rouxa', 'q', 'ó', 'icou', 'ais', 'aro']
# ['etonat13435182', 'fuck_off_matt', 'xatamente', 'ue', 'u', 'aloal', 'enho', 'empo', 'e', 'ogar', 's5', 'u', 's', 'ames', 'e', 's4stou', 'om', 'm', 'acklog', 'normeu', 'cha', 'ue', 'ou', 'e', 'mportar', 'om', 's3', 'á', 'oiá', 'oguei', 'ue', 'ueria', 'a', 'pocainguém', 'igava', 'ra', 's3', 'té', 'ntemo', 'ada', 'irou', 'ídeo', 'ame', 'ais', 'sado', 'ogadoei]']
# ['agazineluiza', 'eses', 'sperando', 'eu', 's5odos', 's', 'razos', 'xpirados', 'em', 'esposta', 'a', 'ojalguém', 'e', 'juda]']
# ['tá', 'i', 'm', 'os', 'otivos', 'ue', 'ão', 'ou', 'omprar', 'm', 's5', 'u', 'utros', 'onsoles', 'a', 'onys', 'aras', 'deiam', 'oje', 'm', 'ia', 'etrocompatibilidade', 'té', 'stão', 'echando', 'ojas', 'e', 'onsoles', 'ntigos', 'omo', 'o', 's3', 'svita', 'em', 'em', 'iquer', 'oder', 'omprar', 'sses', 'ogos', 'o', 's4', 's5eprimentettpsobp1wtash5']
# ['toda', 'ez', 'ue', 'lguém', 'ergunta', 'e', 'u', 'ogo', 'lguma', 'oisa', 'u', 'embro', 'ue', 'm', 'ev020', 'u', 'ava', 'lhando', 'm', 's4', 'or', '600', 'om', 'umores', 'o', 's5', 'a', 'ra', 'ns', '400200ai', 'ólar', 'omeçou', 'ubir', 'oje', 'usta', '600', '🏻']
# ['como', 'everá', 'er', 'ova', 'intendo', 'witchuntando', 's5onsigo', 'uvir', 'arteira', 'horarttpsoawcfbarb2']
# ['ogador76_', 'ceythian', 'playstation', 'í', 'ocê', 'alou', 'udoamer', 'ue', 'amer', 'erá', 'empre', 'avor', 'os', 'ogosor', 'sso', 'negável', 'ue', 'bordagem', 'o', 'box', 'm', 'ferecer', 'etrocompatibilidade', 'té', 'om', 'rimeiro', 'box', 'ensacional', 'em', 'ontar', 'ue', 'em', 'elhorias', 'ráficas', 'azendo', 'so', 'o', 'ovo', 'ardwares5', 'everia', 'er', 'etro]']
# ['boxbr', 'ãoq', 's5', 'elhor']
# ['onystasensato', 'e', 'le', 'eteu', 'oda', 'e', 'o', 's4', 'ue', 'ais', 'e', '15', 'ilhoes', 'e', 'essoas', 'oto', 'lus', 'olection', 'o', 'a', 'magine', 's3', 's', 'utros', 'kk', 'ustava', 'ada', 'elomenos', 'er', 'osto', 'etro', 'om', 's1', 'u', 's2', 'o', 's4', 's5', 'er', 'eito', 'elomenos', 'snow', 'om', 'ogos', 'e', 's3', 'u', 'm', 'or', 'os', 'xclusivos', 'e', 's3', 'ra', 's4']
# ['orvanna', 'ntao', 'ensagem', 'ue', 'u', 'ou', 'oltar', 'o', 'empo', 'er', 'm', 's5', 'om', 'ames', 'om', 'reço', 'e', 'c', 'tf', 'kkkkkkk']
# ['espero', 'ony', 'steja', 'azendo', 'ogada', 'a', 'icrosoftazou', 'otícia', 'a', 's', 'tore', 'echandos', 'ãs', 'ão', 'horandola', 'urge', 'alando', 'ai', 'oder', 'ontinuar', 'aixando', 'ue', 's5', 'oda', 'udo', 'rande', 'eroína']
# ['bloliveira', 'i', 'epende', 'uito', 'o', 'ue', 'ocê', 'ostac', 'em', 'ais', 'ariedades5', 'a', 'ó', 'om', 'lguns', 'ogos', 'inda']
# ['rt', 'xcorujaogora', 'onta', 'ma', 'ovidadeorque', 'ssa', 'o', 'ps5', 'om', 'xbox', 'o', 'onysta', 'ão', 'ettpsovpj6xsu9a']
# ['uiz_fernandorj', 'em', 'm', 'ara', 'ue', 'omprou', 's5', 'odos', 'les', 'eram', 'sm', 'ug', ']']
# ['zisaazx', 'm', 's5', 'as', 'a', 't', 'aro']
# ['aked_dragonn', 'mandogko', 'drakesincero1', 'é', 'as', 's', 'ogos', 'e', 's1', 'á', 'ara', 'ogar', 'o', 'box', 'or', 'mulador', 'kk', 'o', 's5', 'ãovo', 'kkkkkkkkkkkkkkkkkkkkkkkkkk']
# ['ah', 'ente', 'u', 'chei', 'indinho', 's5', 'eio', 'ra', 'orra', 'ttpso50d3o9fvm']
# ['agora', 'onta', 'ma', 'ovidadeorque', 'ssa', 'o', 'ps5', 'om', 'xbox', 'o', 'onysta', 'ão', 'ettpsovpj6xsu9a']
# ['estou', 'o', 'ivo', 'm', 'cyberpunk2077', 'ap', '1', 'xboxone', 'ttpso31bq5tqrb', 'ia', 'facebookgaming', 'games', 'playstation_br', 'ps5', 'games', 'gamer', 'cdprojektred', 'ttpsoie1xqpmby']
# ['todotortou', 'e', 'mo', 'anto', 'e', 'osse', 'ra', 'scolher', 'ntre', 'ocê', 'm', 's5', 'u', 'té', 'entiria', 'ua', 'alta', 'evi', 'assivinho', 'orde', 'ronha', 'ebsub', 'apai', 'u', 'ou', 'e', 'ulgar', 'ois', 'e', 'rocaria', 'or', 'm', 'box', 'ne']
# ['quando', 'ecido', 'omprar', 's5', 'á', 'udo', 'm', 'alta]']
# ['edgama', 'acina', 'eestoque', 'o', 's5']
# ['id_highwind02', 'u', 'ecepcionei', 'im', 'sm', 'kkkkk', 'ó', 'onsegui', 'ogar', 'abe', 'as', 'á', 'os', 'lanos', 'ra', 'ogar', 'gr', 'o', 's5']
# ['rt', 'vih8pxboxseriesx', 'ps5', 'rincadeiraaaaaa😶', 'ttpso3gvnvg11l']
# ['a', 'alta', 'e', 'stoque', 'á', 'escaração', 'a', 'icrosoft', 'ma', 'mpresa', 'e', 'ecnologia', 'omo', 'ssa', 'everia', 'er', 'ontrato', 'eservas', 'eservas', 'e', 'eças', 'ra', 'rodução', 'i', 'essoal', 'arga', 'ão', 'ompra', 's5', 'uando', 'parece', 'ão', 'abe', 'orque']
# ['box', 'eries', 'ma', 'meaça', 'eal', 'ara', 's5onysta', 'ota', 'a', 'abeça', 'ue', 'ogo', 'ó', 'ráficoer', 'ais', 'arato', 'odar', 'odos', 's', 'ogos', 'ale', 'em', 'ais', 'ena', 'ro', 'onsumidor', 'édio', 'ttpsoh06jvdxee']
# ['vestronda', 'acar', 'ogo', 'o', 's5']
# ['aciotenorio8', 'uem', 'ivo', 'empre', 'pareceontinua', 'esma', 'ecepçãostava', 'esde', 'ezembro', 'em', 'ogar', 'omprei', 's5', 'ês', 'assado', 'ontinua', 'ecepção', 'e', 'empre']
# ['show', 'iscord', 'ttpso6oxummoxf', 'iga', 'ossas', 'idias', 'ociais', 'companhe', 'emesoticiasídeos', 'ives', 'aldoriagames', 'memes', 'humor', 'meme', 'nostalgia', 'ps5', 'ps4', 'xbox', 'nintendo', 'ps2', 'ttpsolrdf439fn']
# ['rt', 'regidanteídeo', 'ovottpsoh1nik1spk', 'residentevil6', 'residentevil', 'gaming', 'ps5', 'xboxseriesx', 'residentevil25thanniversary', 'r…']
# ['arcus_vf7', 'ic', 'sbntão', 'u', 'onectei', 'm', 'ma', 'as', 'ntradas', 'a', 'arte', 'e', 'rás', 'o', 's5', 'oi', 'etectado', 'e', 'oass', 'nicas', 'oisas', 'ristes', 'e', 'esolver', 'sses', 'roblemas', 'o', 'róprio', 's', 'ue', 'ada', 'o', 'treamlabs', 'aviso', 'e', 'eguidorarrinha', 'e', 'etatcai', 'parecer', ']']
# ['rembxlaa', 'mxdinafn', 'vxnixy', 'alma', 'e', 'pz', 'crim', 'pen', 'éi', 'eis', 'ao', 'retando', 'u', 'ei', 'ificil', 'egar', 'op', 'om', 'm', 'c', 's5']
# ['bisoftbrasil', 'vento', 'ecorar', 'ila', 'ara', 'im', 'o', 's5', 'sta', 'ugado', 'ão', 'onsigo', 'oncluirão', 'ecorações', 'o', 'parece', 'uando', 'aio', 'a', 'inha', 'idade', 'ou', 'ara', 'utro', 'ugar', 'parece', 'o', 'apa', 'olto', 'ara', 'idade', 'omeoi', 'm', 'vento', 'eito', 'as', 'oxas']
# ['fall', 'uysemporada', 'á', 'stá', 'isponível', 'ttpsogwdlqof41', 'pc', 'ps4', 'noticias', 'ps5', 'fallguysultimateknockout', 'playstation5', 'playstation5']
# ['boxseriesx', 'ps5', 'rincadeiraaaaaa😶', 'ttpso3gvnvg11l']
# ['abrieltrincha', 'thirufio', 'drakesincero1', 'paps', 'ale', 'ãolha', 'ra', 'onte', 'ntãos5', 'eries', 's', 'fiosstruturais', 'á', 'stão', 'ítidos', 'o', 'box', 'eries', 'o', 's5', 'le', 'á', 'odo', 'agadoé]']
# ['atheus_luzzz', 'elo', 'ue', 'u', 'uvi', 'alar', 'ogo', 'a', 'odando', 'em', 'o', 's5', 'as', 'inda', 'a', 'rashando', 'astante']
# ['isterj56569698', 'fuck_off_matt', 'omeçou', 'om', '0', 'eraflopsepois', 'aiu', 'ara', 'sem', 'verclock', 'ntãomisteriosamentefirmarem', 'ue', 'lock', 'ase', 'o', 's5', 'e', '825mhz', 'mesmo', 'lock', 'ue', 'eries', 'endo', 'ssim', 's5', 'eria', 'eraflops', 'epoisoram', 'iminuindo', 'inda', 'ais', 'ara', 'hegar', 'm', 'eraflops]']
# ['uck_off_matt', 'ão', 'ão', 'ostas', 'racos', 'e', 'rgumento', 'le', 'iz', 's5', 'tem', 'fé', 'omo', 'ssim', 'ntão', 'ue', 'izer', 'u', 'osso', 'omprar', 'm', 's5', 'enha', 'om', 'f', 'eu', 'izinho', 'omprar', 'm', 'enha', 'om', 'ão', 'sses', 's', 'esenvolvedores', 'e', 'ofá', 'onseguem', 'em', 'stipular', 'm', 'um', 'xato', 'essa', 'entirakkkk']
# ['as', 'oja', 'ão', 'em', 's5', 'isponível']
# ['altercicero6', 'u', 'credito', 'ue', 'ãoos', 'ompramos', 's', 'ogosode', 'er', 'ue', 'rranjem', 'orma', 'e', 's', 'ransferir', 'ara', 's4', 's5ambém', 'e', 'arece', 'mpossível', 'as', 'ão', 'eixa', 'e', 'er', 'ma', 'oluçãoenho', 'erteza', 'ue', 'ão', 'amos', 'icar', 'em', 's', 'oisas']
# ['estamos', 'nineorre', 'ra', 'ivettpsodpkzdtsbe', 'ttpsozirl0wpun', 'ttpsov6pygxdwf', 'ps4', 'xbox', 'games', 'gamer', 'stremer', 'xboxone', 'gta', 'youtube', 'xboxone', 'ps5', 'pcgamer', 'zerando', 'nostalgia']

# %%
sem_repeticao = []
for i in train0 + train1 + train2:
    if i not in sem_repeticao:
        sem_repeticao.append(i)
#print (len(sem_repeticao))

p_t0 = len(train0)
p_t1 = len(train1)
p_t2 = len(train2)
p_sem_repeticao = len(sem_repeticao)
#print(p_t0, p_t1, p_t2, p_sem_repeticao)

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou entre emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
